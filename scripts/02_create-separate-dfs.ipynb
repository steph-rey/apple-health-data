# %%
# Import packages

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
# Load and preview dataset

df_raw = pd.read_csv('/Users/steph/anaconda_projects/apple-health-data/cleaned-data/apple_health_data_full_export_2025-04-18.csv')
df_raw.head()
# Out:
#                                    type  sourceName unit    value  \
# 0  HKQuantityTypeIdentifierDietaryWater  Cronometer   mL  236.592
# 1  HKQuantityTypeIdentifierDietaryWater  Cronometer   mL  236.592
# 2  HKQuantityTypeIdentifierDietaryWater  Cronometer   mL  236.592
# 3  HKQuantityTypeIdentifierDietaryWater  Cronometer   mL  236.592
# 4  HKQuantityTypeIdentifierDietaryWater  Cronometer   mL  236.592
#
#                    startDate                    endDate        date    month  \
# 0  2025-04-01 18:28:00-07:00  2025-04-01 18:28:00-07:00  2025-04-01  2025-04
# 1  2025-04-01 18:28:00-07:00  2025-04-01 18:28:00-07:00  2025-04-01  2025-04
# 2  2025-04-01 18:28:00-07:00  2025-04-01 18:28:00-07:00  2025-04-01  2025-04
# 3  2025-04-01 18:28:00-07:00  2025-04-01 18:28:00-07:00  2025-04-01  2025-04
# 4  2025-04-01 18:28:00-07:00  2025-04-01 18:28:00-07:00  2025-04-01  2025-04
#
#    year  workout_type
# 0  2025  DietaryWater
# 1  2025  DietaryWater
# 2  2025  DietaryWater
# ...

# %%
df_raw['workout_type'].unique()
# Out:
# array(['DietaryWater', 'BodyMassIndex', 'Height', 'BodyMass', 'HeartRate',
#        'OxygenSaturation', 'RespiratoryRate', 'BodyFatPercentage',
#        'LeanBodyMass', 'StepCount', 'DistanceWalkingRunning',
#        'BasalEnergyBurned', 'ActiveEnergyBurned', 'FlightsClimbed',
#        'DietaryFatTotal', 'DietaryFatPolyunsaturated',
#        'DietaryFatMonounsaturated', 'DietaryFatSaturated',
#        'DietaryCholesterol', 'DietarySodium', 'DietaryCarbohydrates',
#        'DietaryFiber', 'DietarySugar', 'DietaryEnergyConsumed',
#        'DietaryProtein', 'DietaryVitaminA', 'DietaryVitaminB6',
#        'DietaryVitaminB12', 'DietaryVitaminC', 'DietaryVitaminD',
#        'DietaryVitaminE', 'DietaryVitaminK', 'DietaryCalcium',
#        'DietaryIron', 'DietaryThiamin', 'DietaryRiboflavin',
#        'DietaryNiacin', 'DietaryFolate', 'DietaryBiotin',
#        'DietaryPantothenicAcid', 'DietaryPhosphorus', 'DietaryIodine',
#        'DietaryMagnesium', 'DietaryZinc', 'DietarySelenium',
# ...

# %%
# Summarize all columns and metadata 

def summarize_metadata(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'nulls': df.isnull().sum(),
        'unique_values': df.nunique(),
        'sample_values': df.apply(lambda x: ", ".join(map(str, x.dropna().unique()[:3])))
    })
    return summary

metadata_summary = summarize_metadata(df_raw)

# %%
metadata_summary
# Out:
#                 dtype  nulls  unique_values  \
# type           object      0             80
# sourceName     object      0             19
# unit           object      0             23
# value         float64      0         643849
# startDate      object      0        6126105
# endDate        object      0        6119701
# date           object      0           2467
# month          object      0             88
# year            int64      0              9
# workout_type   object      0             80
#
#                                                   sample_values
# type          HKQuantityTypeIdentifierDietaryWater, HKQuanti...
# sourceName                           Cronometer, VeSync, Health
# unit                                              mL, count, ft
# value                                  236.592, 115.655, 62.979
# startDate     2025-04-01 18:28:00-07:00, 2025-04-01 00:00:00...
# endDate       2025-04-01 18:28:00-07:00, 2025-04-01 00:00:00...
# ...

# %%
for col in df_raw.columns:
    print(f"\n📌 Column: '{col}'")
    unique_vals = df_raw[col].dropna().unique()
    print(f"Unique values ({len(unique_vals)}):")
    print(unique_vals)
    unique_vals = sorted(df_raw[col].dropna().unique())
# Out:
# 📌 Column: 'type'
# Unique values (80):
# ['HKQuantityTypeIdentifierDietaryWater'
#  'HKQuantityTypeIdentifierBodyMassIndex' 'HKQuantityTypeIdentifierHeight'
#  'HKQuantityTypeIdentifierBodyMass' 'HKQuantityTypeIdentifierHeartRate'
#  'HKQuantityTypeIdentifierOxygenSaturation'
#  'HKQuantityTypeIdentifierRespiratoryRate'
#  'HKQuantityTypeIdentifierBodyFatPercentage'
#  'HKQuantityTypeIdentifierLeanBodyMass'
#  'HKQuantityTypeIdentifierStepCount'
#  'HKQuantityTypeIdentifierDistanceWalkingRunning'
#  'HKQuantityTypeIdentifierBasalEnergyBurned'
#  'HKQuantityTypeIdentifierActiveEnergyBurned'
#  'HKQuantityTypeIdentifierFlightsClimbed'
#  'HKQuantityTypeIdentifierDietaryFatTotal'
#  'HKQuantityTypeIdentifierDietaryFatPolyunsaturated'
#  'HKQuantityTypeIdentifierDietaryFatMonounsaturated'
#  'HKQuantityTypeIdentifierDietaryFatSaturated'
#  'HKQuantityTypeIdentifierDietaryCholesterol'
#  'HKQuantityTypeIdentifierDietarySodium'
#  'HKQuantityTypeIdentifierDietaryCarbohydrates'
# ...

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9268187 entries, 0 to 9268186
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   type          object
#  1   sourceName    object
#  2   unit          object
#  3   value         float64
#  4   startDate     object
#  5   endDate       object
#  6   date          object
#  7   month         object
#  8   year          int64
#  9   workout_type  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 707.1+ MB

# %%
peloton_data_raw = df_raw[df_raw['sourceName'] == 'Peloton']
peloton_data_raw.info()
peloton_data_raw

# Save as CSV
peloton_data_raw.to_csv('/Users/steph/anaconda_projects/apple-health-data/cleaned-data/peloton_data_raw.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 455319 entries, 18168 to 8551116
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   type          455319 non-null  object
#  1   sourceName    455319 non-null  object
#  2   unit          455319 non-null  object
#  3   value         455319 non-null  float64
#  4   startDate     455319 non-null  object
#  5   endDate       455319 non-null  object
#  6   date          455319 non-null  object
#  7   month         455319 non-null  object
#  8   year          455319 non-null  int64
#  9   workout_type  455319 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 38.2+ MB

# %%
eight_sleep_data_raw = df_raw[df_raw['sourceName'] == 'Eight Sleep']
eight_sleep_data_raw.info()
eight_sleep_data_raw

# Save as CSV
eight_sleep_data_raw.to_csv('/Users/steph/anaconda_projects/apple-health-data/cleaned-data/eight_sleep_data_raw.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8633 entries, 30781 to 1870430
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8633 non-null   object
#  1   sourceName    8633 non-null   object
#  2   unit          8633 non-null   object
#  3   value         8633 non-null   float64
#  4   startDate     8633 non-null   object
#  5   endDate       8633 non-null   object
#  6   date          8633 non-null   object
#  7   month         8633 non-null   object
#  8   year          8633 non-null   int64
#  9   workout_type  8633 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 741.9+ KB

# %%
apl_health_data_raw = df_raw[df_raw['sourceName'] == 'Health']
apl_health_data_raw.info()
apl_health_data_raw

# Save as CSV
apl_health_data_raw.to_csv('/Users/steph/anaconda_projects/apple-health-data/cleaned-data/apl_health_data_raw.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 326 entries, 202 to 8551066
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          326 non-null    object
#  1   sourceName    326 non-null    object
#  2   unit          326 non-null    object
#  3   value         326 non-null    float64
#  4   startDate     326 non-null    object
#  5   endDate       326 non-null    object
#  6   date          326 non-null    object
#  7   month         326 non-null    object
#  8   year          326 non-null    int64
#  9   workout_type  326 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 28.0+ KB

# %%
lose_it_data_raw = df_raw[df_raw['sourceName'] == 'Lose It!']
lose_it_data_raw.info()
lose_it_data_raw

# Save as CSV
lose_it_data_raw.to_csv('/Users/steph/anaconda_projects/apple-health-data/cleaned-data/fitness_tracker_data_raw.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97207 entries, 221 to 8547764
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          97207 non-null  object
#  1   sourceName    97207 non-null  object
#  2   unit          97207 non-null  object
#  3   value         97207 non-null  float64
#  4   startDate     97207 non-null  object
#  5   endDate       97207 non-null  object
#  6   date          97207 non-null  object
#  7   month         97207 non-null  object
#  8   year          97207 non-null  int64
#  9   workout_type  97207 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 8.2+ MB

# %%
apl_watch_data_raw = df_raw[df_raw['sourceName'] == 'Stephanie’s Apple\xa0Watch']
apl_watch_data_raw.info()
apl_watch_data_raw

# Save as CSV
apl_watch_data_raw.to_csv('/Users/steph/anaconda_projects/apple-health-data/cleaned-data/apl_watch_data_raw.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8157678 entries, 317 to 9268186
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   type          object
#  1   sourceName    object
#  2   unit          object
#  3   value         float64
#  4   startDate     object
#  5   endDate       object
#  6   date          object
#  7   month         object
#  8   year          int64
#  9   workout_type  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 684.6+ MB
